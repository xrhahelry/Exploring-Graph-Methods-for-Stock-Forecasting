# %%
import torch
import torch.nn as nn
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from torch_geometric.loader import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool, GATv2Conv
import numpy as np
import matplotlib.pyplot as plt

# %%
class GAT(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(GAT, self).__init__()
        self.conv1 = GATv2Conv(input_size, hidden_size, edge_dim=1)
        self.conv2 = GATv2Conv(hidden_size, hidden_size, edge_dim=1)
        self.lin = nn.Linear(hidden_size, output_size)

    def forward(self, x, edge_index, edge_weight, batch):
        x = self.conv1(x, edge_index, edge_attr=edge_weight)
        x = F.relu(x)
        x = self.conv2(x, edge_index, edge_attr=edge_weight)
        x = F.relu(x)
        x = global_mean_pool(x, batch)
        x = self.lin(x)
        return x

# %%
input_size = 7
hidden_size = 512
output_size = 7
epochs = 500
learning_rate = 5e-3
graph_name = "inv_cit_wt"
batch_size = 32

# %%
graphs = torch.load(f"../graphs/{graph_name}.pt", weights_only=False)
train, val = train_test_split(graphs, test_size=0.2, random_state=12)
train_graphs = DataLoader(train, batch_size=batch_size, shuffle=True)
val_graphs = DataLoader(val, batch_size=batch_size, shuffle=False)

# %%
len(train_graphs)
# Out:
# 20

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = GAT(input_size, hidden_size, output_size)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
warmup_scheduler = torch.optim.lr_scheduler.LinearLR(optimizer, start_factor=0.01, total_iters=1100)
main_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=3500)
scheduler = torch.optim.lr_scheduler.SequentialLR(optimizer, schedulers=[warmup_scheduler, main_scheduler], milestones=[1100])
ls_fn = nn.MSELoss()

best_val_loss = float('inf')
training_loss = []
validation_loss = []

for epoch in range(epochs):
    model.train()
    total_loss = 0
    num_batches = 0
    for batch in train_graphs:
        batch = batch.to(device)
        optimizer.zero_grad()
        output = model(batch.x, batch.edge_index, batch.edge_weight, batch.batch)
        output = output.view(-1)
        loss = ls_fn(output, batch.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        num_batches += 1
    avg_loss = total_loss/num_batches

    model.eval()
    val_loss = 0
    predictions = []
    ground_truth = []
    for batch in val_graphs:
        batch = batch.to(device)
        with torch.no_grad():
            output = model(batch.x, batch.edge_index, batch.edge_weight, batch.batch)
            output = output.view(-1)
            val_loss += ls_fn(output, batch.y).item()
            predictions.append(output.cpu().numpy())
            ground_truth.append(batch.y.cpu().numpy())

    val_loss /= len(val_graphs)
    predictions = np.concatenate(predictions, axis=0)
    ground_truth = np.concatenate(ground_truth, axis=0)

    val_mse = mean_squared_error(ground_truth, predictions)
    val_mae = mean_absolute_error(ground_truth, predictions)

    training_loss.append(avg_loss)
    validation_loss.append(val_loss)

    print(
        f"Epoch: {epoch+1}/{epochs}, Val_Loss: {val_loss:.4f}"
    )
    scheduler.step()
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), "../models/gat_cit.pth")
print(f"MSE: {val_mse:.4f}, MAE: {val_mae:.4f}")
# Out:
# Epoch: 1/500, Val_Loss: 1.0186
# Epoch: 2/500, Val_Loss: 0.9146
# Epoch: 3/500, Val_Loss: 0.8051
# Epoch: 4/500, Val_Loss: 0.6911
# Epoch: 5/500, Val_Loss: 0.5857
# Epoch: 6/500, Val_Loss: 0.5108
# Epoch: 7/500, Val_Loss: 0.4692
# Epoch: 8/500, Val_Loss: 0.4470
# Epoch: 9/500, Val_Loss: 0.4313
# Epoch: 10/500, Val_Loss: 0.4212
# Epoch: 11/500, Val_Loss: 0.4136
# Epoch: 12/500, Val_Loss: 0.4075
# Epoch: 13/500, Val_Loss: 0.4076
# Epoch: 14/500, Val_Loss: 0.4047
# Epoch: 15/500, Val_Loss: 0.4045
# Epoch: 16/500, Val_Loss: 0.4002
# Epoch: 17/500, Val_Loss: 0.4032
# Epoch: 18/500, Val_Loss: 0.3990
# Epoch: 19/500, Val_Loss: 0.4034
# Epoch: 20/500, Val_Loss: 0.4001
# Epoch: 21/500, Val_Loss: 0.3966
# Epoch: 22/500, Val_Loss: 0.3988
# Epoch: 23/500, Val_Loss: 0.4007
# Epoch: 24/500, Val_Loss: 0.4018
# Epoch: 25/500, Val_Loss: 0.3962
# Epoch: 26/500, Val_Loss: 0.3956
# Epoch: 27/500, Val_Loss: 0.3987
# Epoch: 28/500, Val_Loss: 0.3942
# Epoch: 29/500, Val_Loss: 0.4004
# Epoch: 30/500, Val_Loss: 0.3962
# Epoch: 31/500, Val_Loss: 0.3931
# Epoch: 32/500, Val_Loss: 0.3950
# Epoch: 33/500, Val_Loss: 0.3916
# Epoch: 34/500, Val_Loss: 0.3896
# Epoch: 35/500, Val_Loss: 0.3968
# Epoch: 36/500, Val_Loss: 0.3904
# Epoch: 37/500, Val_Loss: 0.3883
# Epoch: 38/500, Val_Loss: 0.3938
# Epoch: 39/500, Val_Loss: 0.3904
# Epoch: 40/500, Val_Loss: 0.3834
# Epoch: 41/500, Val_Loss: 0.3916
# Epoch: 42/500, Val_Loss: 0.3874
# Epoch: 43/500, Val_Loss: 0.3902
# Epoch: 44/500, Val_Loss: 0.3854
# Epoch: 45/500, Val_Loss: 0.3823
# Epoch: 46/500, Val_Loss: 0.3853
# Epoch: 47/500, Val_Loss: 0.3946
# Epoch: 48/500, Val_Loss: 0.3829
# Epoch: 49/500, Val_Loss: 0.3901
# Epoch: 50/500, Val_Loss: 0.3851
# Epoch: 51/500, Val_Loss: 0.3867
# Epoch: 52/500, Val_Loss: 0.3903
# Epoch: 53/500, Val_Loss: 0.3849
# Epoch: 54/500, Val_Loss: 0.3867
# Epoch: 55/500, Val_Loss: 0.3970
# Epoch: 56/500, Val_Loss: 0.4014
# Epoch: 57/500, Val_Loss: 0.3758
# Epoch: 58/500, Val_Loss: 0.3872
# Epoch: 59/500, Val_Loss: 0.3909
# Epoch: 60/500, Val_Loss: 0.3891
# Epoch: 61/500, Val_Loss: 0.3824
# Epoch: 62/500, Val_Loss: 0.3747
# Epoch: 63/500, Val_Loss: 0.3959
# Epoch: 64/500, Val_Loss: 0.3936
# Epoch: 65/500, Val_Loss: 0.3854
# Epoch: 66/500, Val_Loss: 0.3957
# Epoch: 67/500, Val_Loss: 0.3901
# Epoch: 68/500, Val_Loss: 0.3769
# Epoch: 69/500, Val_Loss: 0.3812
# Epoch: 70/500, Val_Loss: 0.3858
# Epoch: 71/500, Val_Loss: 0.3770
# Epoch: 72/500, Val_Loss: 0.3902
# Epoch: 73/500, Val_Loss: 0.3833
# Epoch: 74/500, Val_Loss: 0.3761
# Epoch: 75/500, Val_Loss: 0.3757
# Epoch: 76/500, Val_Loss: 0.3903
# Epoch: 77/500, Val_Loss: 0.3843
# Epoch: 78/500, Val_Loss: 0.3747
# Epoch: 79/500, Val_Loss: 0.3755
# Epoch: 80/500, Val_Loss: 0.3715
# Epoch: 81/500, Val_Loss: 0.3709
# Epoch: 82/500, Val_Loss: 0.3827
# Epoch: 83/500, Val_Loss: 0.3673
# Epoch: 84/500, Val_Loss: 0.3766
# Epoch: 85/500, Val_Loss: 0.3797
# Epoch: 86/500, Val_Loss: 0.3765
# Epoch: 87/500, Val_Loss: 0.3703
# Epoch: 88/500, Val_Loss: 0.3611
# Epoch: 89/500, Val_Loss: 0.3736
# Epoch: 90/500, Val_Loss: 0.3912
# Epoch: 91/500, Val_Loss: 0.3909
# Epoch: 92/500, Val_Loss: 0.3609
# Epoch: 93/500, Val_Loss: 0.3905
# Epoch: 94/500, Val_Loss: 0.3624
# Epoch: 95/500, Val_Loss: 0.3738
# Epoch: 96/500, Val_Loss: 0.3756
# Epoch: 97/500, Val_Loss: 0.3767
# Epoch: 98/500, Val_Loss: 0.3736
# Epoch: 99/500, Val_Loss: 0.3824
# Epoch: 100/500, Val_Loss: 0.3976
# Epoch: 101/500, Val_Loss: 0.3702
# Epoch: 102/500, Val_Loss: 0.3780
# Epoch: 103/500, Val_Loss: 0.3931
# Epoch: 104/500, Val_Loss: 0.3717
# Epoch: 105/500, Val_Loss: 0.3987
# Epoch: 106/500, Val_Loss: 0.3784
# Epoch: 107/500, Val_Loss: 0.3888
# Epoch: 108/500, Val_Loss: 0.3797
# Epoch: 109/500, Val_Loss: 0.3771
# Epoch: 110/500, Val_Loss: 0.3990
# Epoch: 111/500, Val_Loss: 0.3764
# Epoch: 112/500, Val_Loss: 0.3886
# Epoch: 113/500, Val_Loss: 0.3706
# Epoch: 114/500, Val_Loss: 0.3913
# Epoch: 115/500, Val_Loss: 0.3676
# Epoch: 116/500, Val_Loss: 0.3934
# Epoch: 117/500, Val_Loss: 0.3840
# Epoch: 118/500, Val_Loss: 0.3990
# Epoch: 119/500, Val_Loss: 0.3742
# Epoch: 120/500, Val_Loss: 0.3871
# Epoch: 121/500, Val_Loss: 0.3662
# Epoch: 122/500, Val_Loss: 0.3815
# Epoch: 123/500, Val_Loss: 0.3899
# Epoch: 124/500, Val_Loss: 0.3834
# Epoch: 125/500, Val_Loss: 0.3763
# Epoch: 126/500, Val_Loss: 0.3692
# Epoch: 127/500, Val_Loss: 0.3795
# Epoch: 128/500, Val_Loss: 0.3915
# Epoch: 129/500, Val_Loss: 0.3825
# Epoch: 130/500, Val_Loss: 0.3675
# Epoch: 131/500, Val_Loss: 0.3761
# Epoch: 132/500, Val_Loss: 0.3763
# Epoch: 133/500, Val_Loss: 0.3689
# Epoch: 134/500, Val_Loss: 0.3903
# Epoch: 135/500, Val_Loss: 0.3877
# Epoch: 136/500, Val_Loss: 0.3887
# Epoch: 137/500, Val_Loss: 0.3876
# Epoch: 138/500, Val_Loss: 0.3967
# Epoch: 139/500, Val_Loss: 0.3987
# Epoch: 140/500, Val_Loss: 0.3857
# Epoch: 141/500, Val_Loss: 0.3888
# Epoch: 142/500, Val_Loss: 0.3795
# Epoch: 143/500, Val_Loss: 0.3729
# Epoch: 144/500, Val_Loss: 0.4110
# Epoch: 145/500, Val_Loss: 0.4032
# Epoch: 146/500, Val_Loss: 0.3936
# Epoch: 147/500, Val_Loss: 0.4247
# Epoch: 148/500, Val_Loss: 0.3909
# Epoch: 149/500, Val_Loss: 0.3821
# Epoch: 150/500, Val_Loss: 0.3842
# Epoch: 151/500, Val_Loss: 0.3981
# Epoch: 152/500, Val_Loss: 0.3666
# Epoch: 153/500, Val_Loss: 0.4156
# Epoch: 154/500, Val_Loss: 0.3886
# Epoch: 155/500, Val_Loss: 0.3998
# Epoch: 156/500, Val_Loss: 0.3920
# Epoch: 157/500, Val_Loss: 0.3850
# Epoch: 158/500, Val_Loss: 0.3790
# Epoch: 159/500, Val_Loss: 0.4157
# Epoch: 160/500, Val_Loss: 0.3895
# Epoch: 161/500, Val_Loss: 0.4019
# Epoch: 162/500, Val_Loss: 0.3874
# Epoch: 163/500, Val_Loss: 0.4269
# Epoch: 164/500, Val_Loss: 0.3712
# Epoch: 165/500, Val_Loss: 0.3940
# Epoch: 166/500, Val_Loss: 0.4090
# Epoch: 167/500, Val_Loss: 0.4336
# Epoch: 168/500, Val_Loss: 0.4262
# Epoch: 169/500, Val_Loss: 0.3818
# Epoch: 170/500, Val_Loss: 0.3980
# Epoch: 171/500, Val_Loss: 0.4226
# Epoch: 172/500, Val_Loss: 0.3676
# Epoch: 173/500, Val_Loss: 0.4081
# Epoch: 174/500, Val_Loss: 0.3916
# Epoch: 175/500, Val_Loss: 0.4007
# Epoch: 176/500, Val_Loss: 0.4066
# Epoch: 177/500, Val_Loss: 0.3745
# Epoch: 178/500, Val_Loss: 0.3733
# Epoch: 179/500, Val_Loss: 0.3928
# Epoch: 180/500, Val_Loss: 0.3969
# Epoch: 181/500, Val_Loss: 0.4159
# Epoch: 182/500, Val_Loss: 0.4154
# Epoch: 183/500, Val_Loss: 0.4142
# Epoch: 184/500, Val_Loss: 0.3936
# Epoch: 185/500, Val_Loss: 0.3936
# Epoch: 186/500, Val_Loss: 0.3988
# Epoch: 187/500, Val_Loss: 0.4240
# Epoch: 188/500, Val_Loss: 0.3723
# Epoch: 189/500, Val_Loss: 0.4368
# Epoch: 190/500, Val_Loss: 0.4176
# Epoch: 191/500, Val_Loss: 0.3533
# Epoch: 192/500, Val_Loss: 0.3881
# Epoch: 193/500, Val_Loss: 0.3761
# Epoch: 194/500, Val_Loss: 0.3821
# Epoch: 195/500, Val_Loss: 0.4309
# Epoch: 196/500, Val_Loss: 0.3791
# Epoch: 197/500, Val_Loss: 0.4051
# Epoch: 198/500, Val_Loss: 0.4460
# Epoch: 199/500, Val_Loss: 0.3501
# Epoch: 200/500, Val_Loss: 0.4254
# Epoch: 201/500, Val_Loss: 0.3663
# Epoch: 202/500, Val_Loss: 0.3830
# Epoch: 203/500, Val_Loss: 0.3708
# Epoch: 204/500, Val_Loss: 0.4187
# Epoch: 205/500, Val_Loss: 0.4432
# Epoch: 206/500, Val_Loss: 0.3587
# Epoch: 207/500, Val_Loss: 0.4139
# Epoch: 208/500, Val_Loss: 0.3885
# Epoch: 209/500, Val_Loss: 0.3685
# Epoch: 210/500, Val_Loss: 0.4267
# Epoch: 211/500, Val_Loss: 0.3901
# Epoch: 212/500, Val_Loss: 0.3683
# Epoch: 213/500, Val_Loss: 0.4043
# Epoch: 214/500, Val_Loss: 0.4281
# Epoch: 215/500, Val_Loss: 0.3872
# Epoch: 216/500, Val_Loss: 0.3851
# Epoch: 217/500, Val_Loss: 0.4007
# Epoch: 218/500, Val_Loss: 0.4136
# Epoch: 219/500, Val_Loss: 0.3814
# Epoch: 220/500, Val_Loss: 0.4088
# Epoch: 221/500, Val_Loss: 0.4537
# Epoch: 222/500, Val_Loss: 0.3803
# Epoch: 223/500, Val_Loss: 0.3966
# Epoch: 224/500, Val_Loss: 0.3752
# Epoch: 225/500, Val_Loss: 0.4048
# Epoch: 226/500, Val_Loss: 0.4012
# Epoch: 227/500, Val_Loss: 0.3998
# Epoch: 228/500, Val_Loss: 0.3904
# Epoch: 229/500, Val_Loss: 0.3947
# Epoch: 230/500, Val_Loss: 0.4314
# Epoch: 231/500, Val_Loss: 0.3726
# Epoch: 232/500, Val_Loss: 0.4105
# Epoch: 233/500, Val_Loss: 0.3793
# Epoch: 234/500, Val_Loss: 0.3945
# Epoch: 235/500, Val_Loss: 0.3815
# Epoch: 236/500, Val_Loss: 0.3738
# Epoch: 237/500, Val_Loss: 0.4268
# Epoch: 238/500, Val_Loss: 0.3890
# Epoch: 239/500, Val_Loss: 0.4157
# Epoch: 240/500, Val_Loss: 0.3622
# Epoch: 241/500, Val_Loss: 0.3750
# Epoch: 242/500, Val_Loss: 0.3988
# Epoch: 243/500, Val_Loss: 0.4156
# Epoch: 244/500, Val_Loss: 0.3768
# Epoch: 245/500, Val_Loss: 0.3971
# Epoch: 246/500, Val_Loss: 0.3493
# Epoch: 247/500, Val_Loss: 0.4120
# Epoch: 248/500, Val_Loss: 0.3796
# Epoch: 249/500, Val_Loss: 0.4226
# Epoch: 250/500, Val_Loss: 0.3931
# Epoch: 251/500, Val_Loss: 0.4741
# Epoch: 252/500, Val_Loss: 0.4094
# Epoch: 253/500, Val_Loss: 0.3665
# Epoch: 254/500, Val_Loss: 0.4362
# Epoch: 255/500, Val_Loss: 0.3639
# Epoch: 256/500, Val_Loss: 0.3923
# Epoch: 257/500, Val_Loss: 0.4038
# Epoch: 258/500, Val_Loss: 0.4351
# Epoch: 259/500, Val_Loss: 0.3857
# Epoch: 260/500, Val_Loss: 0.3844
# Epoch: 261/500, Val_Loss: 0.3957
# Epoch: 262/500, Val_Loss: 0.3891
# Epoch: 263/500, Val_Loss: 0.4067
# Epoch: 264/500, Val_Loss: 0.3537
# Epoch: 265/500, Val_Loss: 0.4031
# Epoch: 266/500, Val_Loss: 0.4067
# Epoch: 267/500, Val_Loss: 0.3560
# Epoch: 268/500, Val_Loss: 0.3728
# Epoch: 269/500, Val_Loss: 0.3860
# Epoch: 270/500, Val_Loss: 0.3779
# Epoch: 271/500, Val_Loss: 0.4125
# Epoch: 272/500, Val_Loss: 0.4740
# Epoch: 273/500, Val_Loss: 0.4096
# Epoch: 274/500, Val_Loss: 0.4342
# Epoch: 275/500, Val_Loss: 0.3425
# Epoch: 276/500, Val_Loss: 0.3919
# Epoch: 277/500, Val_Loss: 0.4094
# Epoch: 278/500, Val_Loss: 0.3663
# Epoch: 279/500, Val_Loss: 0.4271
# Epoch: 280/500, Val_Loss: 0.4641
# Epoch: 281/500, Val_Loss: 0.4359
# Epoch: 282/500, Val_Loss: 0.3650
# Epoch: 283/500, Val_Loss: 0.4212
# Epoch: 284/500, Val_Loss: 0.3773
# Epoch: 285/500, Val_Loss: 0.4217
# Epoch: 286/500, Val_Loss: 0.3326
# Epoch: 287/500, Val_Loss: 0.4209
# Epoch: 288/500, Val_Loss: 0.4243
# Epoch: 289/500, Val_Loss: 0.4120
# Epoch: 290/500, Val_Loss: 0.3745
# Epoch: 291/500, Val_Loss: 0.3832
# Epoch: 292/500, Val_Loss: 0.3768
# Epoch: 293/500, Val_Loss: 0.3778
# Epoch: 294/500, Val_Loss: 0.3834
# Epoch: 295/500, Val_Loss: 0.3909
# Epoch: 296/500, Val_Loss: 0.3197
# Epoch: 297/500, Val_Loss: 0.3923
# Epoch: 298/500, Val_Loss: 0.4569
# Epoch: 299/500, Val_Loss: 0.3836
# Epoch: 300/500, Val_Loss: 0.3886
# Epoch: 301/500, Val_Loss: 0.4076
# Epoch: 302/500, Val_Loss: 0.3672
# Epoch: 303/500, Val_Loss: 0.4181
# Epoch: 304/500, Val_Loss: 0.3739
# Epoch: 305/500, Val_Loss: 0.4201
# Epoch: 306/500, Val_Loss: 0.3729
# Epoch: 307/500, Val_Loss: 0.4366
# Epoch: 308/500, Val_Loss: 0.4151
# Epoch: 309/500, Val_Loss: 0.3348
# Epoch: 310/500, Val_Loss: 0.4121
# Epoch: 311/500, Val_Loss: 0.4499
# Epoch: 312/500, Val_Loss: 0.4124
# Epoch: 313/500, Val_Loss: 0.3480
# Epoch: 314/500, Val_Loss: 0.3869
# Epoch: 315/500, Val_Loss: 0.3797
# Epoch: 316/500, Val_Loss: 0.4021
# Epoch: 317/500, Val_Loss: 0.4121
# Epoch: 318/500, Val_Loss: 0.4160
# Epoch: 319/500, Val_Loss: 0.3551
# Epoch: 320/500, Val_Loss: 0.4022
# Epoch: 321/500, Val_Loss: 0.4273
# Epoch: 322/500, Val_Loss: 0.4018
# Epoch: 323/500, Val_Loss: 0.3946
# Epoch: 324/500, Val_Loss: 0.3639
# Epoch: 325/500, Val_Loss: 0.4154
# Epoch: 326/500, Val_Loss: 0.3701
# Epoch: 327/500, Val_Loss: 0.4459
# Epoch: 328/500, Val_Loss: 0.3342
# Epoch: 329/500, Val_Loss: 0.4088
# Epoch: 330/500, Val_Loss: 0.4112
# Epoch: 331/500, Val_Loss: 0.3970
# Epoch: 332/500, Val_Loss: 0.3933
# Epoch: 333/500, Val_Loss: 0.4018
# Epoch: 334/500, Val_Loss: 0.3816
# Epoch: 335/500, Val_Loss: 0.3994
# Epoch: 336/500, Val_Loss: 0.3570
# Epoch: 337/500, Val_Loss: 0.3514
# Epoch: 338/500, Val_Loss: 0.3567
# Epoch: 339/500, Val_Loss: 0.4142
# Epoch: 340/500, Val_Loss: 0.4077
# Epoch: 341/500, Val_Loss: 0.3578
# Epoch: 342/500, Val_Loss: 0.4305
# Epoch: 343/500, Val_Loss: 0.3824
# Epoch: 344/500, Val_Loss: 0.4338
# Epoch: 345/500, Val_Loss: 0.4051
# Epoch: 346/500, Val_Loss: 0.3820
# Epoch: 347/500, Val_Loss: 0.3463
# Epoch: 348/500, Val_Loss: 0.3945
# Epoch: 349/500, Val_Loss: 0.3768
# Epoch: 350/500, Val_Loss: 0.3198
# Epoch: 351/500, Val_Loss: 0.4142
# Epoch: 352/500, Val_Loss: 0.3902
# Epoch: 353/500, Val_Loss: 0.3585
# Epoch: 354/500, Val_Loss: 0.4471
# Epoch: 355/500, Val_Loss: 0.3328
# Epoch: 356/500, Val_Loss: 0.4151
# Epoch: 357/500, Val_Loss: 0.3870
# Epoch: 358/500, Val_Loss: 0.3639
# Epoch: 359/500, Val_Loss: 0.3892
# Epoch: 360/500, Val_Loss: 0.4145
# Epoch: 361/500, Val_Loss: 0.3703
# Epoch: 362/500, Val_Loss: 0.3978
# Epoch: 363/500, Val_Loss: 0.3682
# Epoch: 364/500, Val_Loss: 0.3755
# Epoch: 365/500, Val_Loss: 0.3535
# Epoch: 366/500, Val_Loss: 0.3794
# Epoch: 367/500, Val_Loss: 0.3991
# Epoch: 368/500, Val_Loss: 0.3946
# Epoch: 369/500, Val_Loss: 0.3773
# Epoch: 370/500, Val_Loss: 0.4119
# Epoch: 371/500, Val_Loss: 0.3594
# Epoch: 372/500, Val_Loss: 0.3835
# Epoch: 373/500, Val_Loss: 0.3944
# Epoch: 374/500, Val_Loss: 0.3762
# Epoch: 375/500, Val_Loss: 0.4029
# Epoch: 376/500, Val_Loss: 0.4242
# Epoch: 377/500, Val_Loss: 0.3894
# Epoch: 378/500, Val_Loss: 0.3500
# Epoch: 379/500, Val_Loss: 0.3808
# Epoch: 380/500, Val_Loss: 0.3912
# Epoch: 381/500, Val_Loss: 0.4873
# Epoch: 382/500, Val_Loss: 0.3633
# Epoch: 383/500, Val_Loss: 0.3977
# Epoch: 384/500, Val_Loss: 0.3757
# Epoch: 385/500, Val_Loss: 0.3710
# Epoch: 386/500, Val_Loss: 0.3522
# Epoch: 387/500, Val_Loss: 0.3674
# Epoch: 388/500, Val_Loss: 0.3755
# Epoch: 389/500, Val_Loss: 0.3733
# Epoch: 390/500, Val_Loss: 0.3663
# Epoch: 391/500, Val_Loss: 0.4083
# Epoch: 392/500, Val_Loss: 0.3937
# Epoch: 393/500, Val_Loss: 0.3560
# Epoch: 394/500, Val_Loss: 0.4391
# Epoch: 395/500, Val_Loss: 0.3993
# Epoch: 396/500, Val_Loss: 0.3668
# Epoch: 397/500, Val_Loss: 0.4006
# Epoch: 398/500, Val_Loss: 0.3784
# Epoch: 399/500, Val_Loss: 0.4018
# Epoch: 400/500, Val_Loss: 0.4437
# Epoch: 401/500, Val_Loss: 0.3801
# Epoch: 402/500, Val_Loss: 0.3697
# Epoch: 403/500, Val_Loss: 0.4148
# Epoch: 404/500, Val_Loss: 0.3656
# Epoch: 405/500, Val_Loss: 0.3517
# Epoch: 406/500, Val_Loss: 0.3989
# Epoch: 407/500, Val_Loss: 0.4142
# Epoch: 408/500, Val_Loss: 0.3840
# Epoch: 409/500, Val_Loss: 0.4205
# Epoch: 410/500, Val_Loss: 0.3674
# Epoch: 411/500, Val_Loss: 0.4339
# Epoch: 412/500, Val_Loss: 0.3921
# Epoch: 413/500, Val_Loss: 0.3727
# Epoch: 414/500, Val_Loss: 0.3766
# Epoch: 415/500, Val_Loss: 0.3656
# Epoch: 416/500, Val_Loss: 0.3832
# Epoch: 417/500, Val_Loss: 0.4124
# Epoch: 418/500, Val_Loss: 0.3609
# Epoch: 419/500, Val_Loss: 0.3880
# Epoch: 420/500, Val_Loss: 0.3625
# Epoch: 421/500, Val_Loss: 0.3601
# Epoch: 422/500, Val_Loss: 0.4031
# Epoch: 423/500, Val_Loss: 0.3952
# Epoch: 424/500, Val_Loss: 0.4006
# Epoch: 425/500, Val_Loss: 0.4396
# Epoch: 426/500, Val_Loss: 0.3552
# Epoch: 427/500, Val_Loss: 0.3821
# Epoch: 428/500, Val_Loss: 0.3585
# Epoch: 429/500, Val_Loss: 0.3698
# Epoch: 430/500, Val_Loss: 0.3587
# Epoch: 431/500, Val_Loss: 0.4248
# Epoch: 432/500, Val_Loss: 0.3787
# Epoch: 433/500, Val_Loss: 0.3827
# Epoch: 434/500, Val_Loss: 0.3776
# Epoch: 435/500, Val_Loss: 0.3693
# Epoch: 436/500, Val_Loss: 0.3854
# Epoch: 437/500, Val_Loss: 0.3777
# Epoch: 438/500, Val_Loss: 0.3846
# Epoch: 439/500, Val_Loss: 0.3655
# Epoch: 440/500, Val_Loss: 0.3694
# Epoch: 441/500, Val_Loss: 0.3902
# Epoch: 442/500, Val_Loss: 0.3823
# Epoch: 443/500, Val_Loss: 0.3774
# Epoch: 444/500, Val_Loss: 0.5192
# Epoch: 445/500, Val_Loss: 0.4227
# Epoch: 446/500, Val_Loss: 0.3915
# Epoch: 447/500, Val_Loss: 0.3470
# Epoch: 448/500, Val_Loss: 0.3835
# Epoch: 449/500, Val_Loss: 0.3769
# Epoch: 450/500, Val_Loss: 0.3824
# Epoch: 451/500, Val_Loss: 0.3779
# Epoch: 452/500, Val_Loss: 0.3937
# Epoch: 453/500, Val_Loss: 0.3866
# Epoch: 454/500, Val_Loss: 0.3828
# Epoch: 455/500, Val_Loss: 0.4345
# Epoch: 456/500, Val_Loss: 0.4321
# Epoch: 457/500, Val_Loss: 0.3742
# Epoch: 458/500, Val_Loss: 0.4624
# Epoch: 459/500, Val_Loss: 0.3736
# Epoch: 460/500, Val_Loss: 0.4051
# Epoch: 461/500, Val_Loss: 0.3645
# Epoch: 462/500, Val_Loss: 0.3786
# Epoch: 463/500, Val_Loss: 0.3790
# Epoch: 464/500, Val_Loss: 0.3730
# Epoch: 465/500, Val_Loss: 0.3645
# Epoch: 466/500, Val_Loss: 0.3667
# Epoch: 467/500, Val_Loss: 0.3876
# Epoch: 468/500, Val_Loss: 0.4017
# Epoch: 469/500, Val_Loss: 0.3543
# Epoch: 470/500, Val_Loss: 0.3791
# Epoch: 471/500, Val_Loss: 0.4397
# Epoch: 472/500, Val_Loss: 0.3876
# Epoch: 473/500, Val_Loss: 0.3630
# Epoch: 474/500, Val_Loss: 0.3797
# Epoch: 475/500, Val_Loss: 0.3790
# Epoch: 476/500, Val_Loss: 0.4070
# Epoch: 477/500, Val_Loss: 0.4180
# Epoch: 478/500, Val_Loss: 0.3829
# Epoch: 479/500, Val_Loss: 0.4122
# Epoch: 480/500, Val_Loss: 0.3714
# Epoch: 481/500, Val_Loss: 0.4460
# Epoch: 482/500, Val_Loss: 0.4008
# Epoch: 483/500, Val_Loss: 0.3957
# Epoch: 484/500, Val_Loss: 0.3896
# Epoch: 485/500, Val_Loss: 0.4387
# Epoch: 486/500, Val_Loss: 0.4109
# Epoch: 487/500, Val_Loss: 0.3651
# Epoch: 488/500, Val_Loss: 0.4325
# Epoch: 489/500, Val_Loss: 0.4011
# Epoch: 490/500, Val_Loss: 0.5540
# Epoch: 491/500, Val_Loss: 0.4224
# Epoch: 492/500, Val_Loss: 0.3918
# Epoch: 493/500, Val_Loss: 0.4526
# Epoch: 494/500, Val_Loss: 0.4069
# Epoch: 495/500, Val_Loss: 0.3966
# Epoch: 496/500, Val_Loss: 0.4414
# Epoch: 497/500, Val_Loss: 0.3532
# Epoch: 498/500, Val_Loss: 0.3650
# Epoch: 499/500, Val_Loss: 0.4276
# Epoch: 500/500, Val_Loss: 0.4653
# MSE: 0.4633, MAE: 0.2918

# %%
epochs = range(1, epochs+1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, training_loss, label="Training loss", color="blue", linestyle="--", linewidth=2)
plt.plot(epochs, validation_loss, label="Validation loss", color="orange", linestyle="-", linewidth=2)

plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Loss", fontsize=14)
plt.title("Loss vs. Epochs for CIT Investment", fontsize=16, weight="bold")

plt.grid(color="gray", linestyle="--", linewidth=0.5, alpha=0.7)

plt.legend(fontsize=12)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()
