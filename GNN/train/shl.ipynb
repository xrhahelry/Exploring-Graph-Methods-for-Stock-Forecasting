# %%
import torch
import torch.nn as nn
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from torch_geometric.loader import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool, GATv2Conv
import numpy as np
import matplotlib.pyplot as plt

# %%
class GAT(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(GAT, self).__init__()
        self.conv1 = GATv2Conv(input_size, hidden_size, edge_dim=1)
        self.conv2 = GATv2Conv(hidden_size, hidden_size, edge_dim=1)
        self.lin = nn.Linear(hidden_size, output_size)

    def forward(self, x, edge_index, edge_weight, batch):
        x = self.conv1(x, edge_index, edge_attr=edge_weight)
        x = F.relu(x)
        x = self.conv2(x, edge_index, edge_attr=edge_weight)
        x = F.relu(x)
        x = global_mean_pool(x, batch)
        x = self.lin(x)
        return x

# %%
input_size = 7
hidden_size = 512
output_size = 7
epochs = 500
learning_rate = 1e-2
graph_name = "ht_shl_wt"
batch_size = 32

# %%
graphs = torch.load(f"../graphs/{graph_name}.pt", weights_only=False)
train, val = train_test_split(graphs, test_size=0.2, random_state=12)
train_graphs = DataLoader(train, batch_size=batch_size, shuffle=True)
val_graphs = DataLoader(val, batch_size=batch_size, shuffle=False)

# %%
len(train_graphs)
# Out:
# 21

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = GAT(input_size, hidden_size, output_size)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
warmup_scheduler = torch.optim.lr_scheduler.LinearLR(optimizer, start_factor=0.01, total_iters=1150)
main_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=3450)
scheduler = torch.optim.lr_scheduler.SequentialLR(optimizer, schedulers=[warmup_scheduler, main_scheduler], milestones=[1150])
ls_fn = nn.MSELoss()

best_val_loss = float('inf')
training_loss = []
validation_loss = []

for epoch in range(epochs):
    model.train()
    total_loss = 0
    num_batches = 0
    for batch in train_graphs:
        batch = batch.to(device)
        optimizer.zero_grad()
        output = model(batch.x, batch.edge_index, batch.edge_weight, batch.batch)
        output = output.view(-1)
        loss = ls_fn(output, batch.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        num_batches += 1
    avg_loss = total_loss/num_batches

    model.eval()
    val_loss = 0
    predictions = []
    ground_truth = []
    for batch in val_graphs:
        batch = batch.to(device)
        with torch.no_grad():
            output = model(batch.x, batch.edge_index, batch.edge_weight, batch.batch)
            output = output.view(-1)
            val_loss += ls_fn(output, batch.y).item()
            predictions.append(output.cpu().numpy())
            ground_truth.append(batch.y.cpu().numpy())

    val_loss /= len(val_graphs)
    predictions = np.concatenate(predictions, axis=0)
    ground_truth = np.concatenate(ground_truth, axis=0)

    val_mse = mean_squared_error(ground_truth, predictions)
    val_mae = mean_absolute_error(ground_truth, predictions)

    training_loss.append(avg_loss)
    validation_loss.append(val_loss)

    print(
        f"Epoch: {epoch+1}/{epochs}, Val_Loss: {val_loss:.4f}"
    )
    scheduler.step()
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), "../models/gat_shl.pth")
print(f"MSE: {val_mse:.4f}, MAE: {val_mae:.4f}")
# Out:
# Epoch: 1/500, Val_Loss: 0.6195
# Epoch: 2/500, Val_Loss: 0.4285
# Epoch: 3/500, Val_Loss: 0.2774
# Epoch: 4/500, Val_Loss: 0.2164
# Epoch: 5/500, Val_Loss: 0.1893
# Epoch: 6/500, Val_Loss: 0.1732
# Epoch: 7/500, Val_Loss: 0.1682
# Epoch: 8/500, Val_Loss: 0.1660
# Epoch: 9/500, Val_Loss: 0.1658
# Epoch: 10/500, Val_Loss: 0.1645
# Epoch: 11/500, Val_Loss: 0.1610
# Epoch: 12/500, Val_Loss: 0.1608
# Epoch: 13/500, Val_Loss: 0.1583
# Epoch: 14/500, Val_Loss: 0.1596
# Epoch: 15/500, Val_Loss: 0.1551
# Epoch: 16/500, Val_Loss: 0.1554
# Epoch: 17/500, Val_Loss: 0.1556
# Epoch: 18/500, Val_Loss: 0.1516
# Epoch: 19/500, Val_Loss: 0.1475
# Epoch: 20/500, Val_Loss: 0.1497
# Epoch: 21/500, Val_Loss: 0.1465
# Epoch: 22/500, Val_Loss: 0.1401
# Epoch: 23/500, Val_Loss: 0.1429
# Epoch: 24/500, Val_Loss: 0.1406
# Epoch: 25/500, Val_Loss: 0.1398
# Epoch: 26/500, Val_Loss: 0.1405
# Epoch: 27/500, Val_Loss: 0.1435
# Epoch: 28/500, Val_Loss: 0.1403
# Epoch: 29/500, Val_Loss: 0.1369
# Epoch: 30/500, Val_Loss: 0.1382
# Epoch: 31/500, Val_Loss: 0.1358
# Epoch: 32/500, Val_Loss: 0.1362
# Epoch: 33/500, Val_Loss: 0.1340
# Epoch: 34/500, Val_Loss: 0.1376
# Epoch: 35/500, Val_Loss: 0.1387
# Epoch: 36/500, Val_Loss: 0.1328
# Epoch: 37/500, Val_Loss: 0.1387
# Epoch: 38/500, Val_Loss: 0.1401
# Epoch: 39/500, Val_Loss: 0.1442
# Epoch: 40/500, Val_Loss: 0.1393
# Epoch: 41/500, Val_Loss: 0.1324
# Epoch: 42/500, Val_Loss: 0.1391
# Epoch: 43/500, Val_Loss: 0.1395
# Epoch: 44/500, Val_Loss: 0.1323
# Epoch: 45/500, Val_Loss: 0.1404
# Epoch: 46/500, Val_Loss: 0.1372
# Epoch: 47/500, Val_Loss: 0.1322
# Epoch: 48/500, Val_Loss: 0.1437
# Epoch: 49/500, Val_Loss: 0.1318
# Epoch: 50/500, Val_Loss: 0.1385
# Epoch: 51/500, Val_Loss: 0.1426
# Epoch: 52/500, Val_Loss: 0.1394
# Epoch: 53/500, Val_Loss: 0.1377
# Epoch: 54/500, Val_Loss: 0.1430
# Epoch: 55/500, Val_Loss: 0.1348
# Epoch: 56/500, Val_Loss: 0.1382
# Epoch: 57/500, Val_Loss: 0.1433
# Epoch: 58/500, Val_Loss: 0.1360
# Epoch: 59/500, Val_Loss: 0.1422
# Epoch: 60/500, Val_Loss: 0.1343
# Epoch: 61/500, Val_Loss: 0.1423
# Epoch: 62/500, Val_Loss: 0.1367
# Epoch: 63/500, Val_Loss: 0.1447
# Epoch: 64/500, Val_Loss: 0.1420
# Epoch: 65/500, Val_Loss: 0.1336
# Epoch: 66/500, Val_Loss: 0.1372
# Epoch: 67/500, Val_Loss: 0.1443
# Epoch: 68/500, Val_Loss: 0.1412
# Epoch: 69/500, Val_Loss: 0.1616
# Epoch: 70/500, Val_Loss: 0.1326
# Epoch: 71/500, Val_Loss: 0.1431
# Epoch: 72/500, Val_Loss: 0.1367
# Epoch: 73/500, Val_Loss: 0.1366
# Epoch: 74/500, Val_Loss: 0.1536
# Epoch: 75/500, Val_Loss: 0.1373
# Epoch: 76/500, Val_Loss: 0.1332
# Epoch: 77/500, Val_Loss: 0.1379
# Epoch: 78/500, Val_Loss: 0.1380
# Epoch: 79/500, Val_Loss: 0.1398
# Epoch: 80/500, Val_Loss: 0.1410
# Epoch: 81/500, Val_Loss: 0.1509
# Epoch: 82/500, Val_Loss: 0.1395
# Epoch: 83/500, Val_Loss: 0.1553
# Epoch: 84/500, Val_Loss: 0.1317
# Epoch: 85/500, Val_Loss: 0.1485
# Epoch: 86/500, Val_Loss: 0.1392
# Epoch: 87/500, Val_Loss: 0.1439
# Epoch: 88/500, Val_Loss: 0.1404
# Epoch: 89/500, Val_Loss: 0.1481
# Epoch: 90/500, Val_Loss: 0.1382
# Epoch: 91/500, Val_Loss: 0.1661
# Epoch: 92/500, Val_Loss: 0.1417
# Epoch: 93/500, Val_Loss: 0.1450
# Epoch: 94/500, Val_Loss: 0.1395
# Epoch: 95/500, Val_Loss: 0.1578
# Epoch: 96/500, Val_Loss: 0.1726
# Epoch: 97/500, Val_Loss: 0.1521
# Epoch: 98/500, Val_Loss: 0.1472
# Epoch: 99/500, Val_Loss: 0.1580
# Epoch: 100/500, Val_Loss: 0.1445
# Epoch: 101/500, Val_Loss: 0.1536
# Epoch: 102/500, Val_Loss: 0.1497
# Epoch: 103/500, Val_Loss: 0.1536
# Epoch: 104/500, Val_Loss: 0.1448
# Epoch: 105/500, Val_Loss: 0.1507
# Epoch: 106/500, Val_Loss: 0.1453
# Epoch: 107/500, Val_Loss: 0.1604
# Epoch: 108/500, Val_Loss: 0.1561
# Epoch: 109/500, Val_Loss: 0.1558
# Epoch: 110/500, Val_Loss: 0.1485
# Epoch: 111/500, Val_Loss: 0.1506
# Epoch: 112/500, Val_Loss: 0.1652
# Epoch: 113/500, Val_Loss: 0.1557
# Epoch: 114/500, Val_Loss: 0.1506
# Epoch: 115/500, Val_Loss: 0.1623
# Epoch: 116/500, Val_Loss: 0.1543
# Epoch: 117/500, Val_Loss: 0.1567
# Epoch: 118/500, Val_Loss: 0.1520
# Epoch: 119/500, Val_Loss: 0.1570
# Epoch: 120/500, Val_Loss: 0.1607
# Epoch: 121/500, Val_Loss: 0.1511
# Epoch: 122/500, Val_Loss: 0.1541
# Epoch: 123/500, Val_Loss: 0.1612
# Epoch: 124/500, Val_Loss: 0.1544
# Epoch: 125/500, Val_Loss: 0.1638
# Epoch: 126/500, Val_Loss: 0.1564
# Epoch: 127/500, Val_Loss: 0.1607
# Epoch: 128/500, Val_Loss: 0.1563
# Epoch: 129/500, Val_Loss: 0.1503
# Epoch: 130/500, Val_Loss: 0.1717
# Epoch: 131/500, Val_Loss: 0.1603
# Epoch: 132/500, Val_Loss: 0.1637
# Epoch: 133/500, Val_Loss: 0.1571
# Epoch: 134/500, Val_Loss: 0.1698
# Epoch: 135/500, Val_Loss: 0.1745
# Epoch: 136/500, Val_Loss: 0.1580
# Epoch: 137/500, Val_Loss: 0.1655
# Epoch: 138/500, Val_Loss: 0.1611
# Epoch: 139/500, Val_Loss: 0.1551
# Epoch: 140/500, Val_Loss: 0.1597
# Epoch: 141/500, Val_Loss: 0.1589
# Epoch: 142/500, Val_Loss: 0.1625
# Epoch: 143/500, Val_Loss: 0.1700
# Epoch: 144/500, Val_Loss: 0.1739
# Epoch: 145/500, Val_Loss: 0.1789
# Epoch: 146/500, Val_Loss: 0.1643
# Epoch: 147/500, Val_Loss: 0.1528
# Epoch: 148/500, Val_Loss: 0.1663
# Epoch: 149/500, Val_Loss: 0.1865
# Epoch: 150/500, Val_Loss: 0.1618
# Epoch: 151/500, Val_Loss: 0.1645
# Epoch: 152/500, Val_Loss: 0.1576
# Epoch: 153/500, Val_Loss: 0.1552
# Epoch: 154/500, Val_Loss: 0.1527
# Epoch: 155/500, Val_Loss: 0.1753
# Epoch: 156/500, Val_Loss: 0.1598
# Epoch: 157/500, Val_Loss: 0.1587
# Epoch: 158/500, Val_Loss: 0.1764
# Epoch: 159/500, Val_Loss: 0.1622
# Epoch: 160/500, Val_Loss: 0.1589
# Epoch: 161/500, Val_Loss: 0.1626
# Epoch: 162/500, Val_Loss: 0.1668
# Epoch: 163/500, Val_Loss: 0.1594
# Epoch: 164/500, Val_Loss: 0.1606
# Epoch: 165/500, Val_Loss: 0.1644
# Epoch: 166/500, Val_Loss: 0.1620
# Epoch: 167/500, Val_Loss: 0.1861
# Epoch: 168/500, Val_Loss: 0.1701
# Epoch: 169/500, Val_Loss: 0.1565
# Epoch: 170/500, Val_Loss: 0.1665
# Epoch: 171/500, Val_Loss: 0.1696
# Epoch: 172/500, Val_Loss: 0.1718
# Epoch: 173/500, Val_Loss: 0.1686
# Epoch: 174/500, Val_Loss: 0.1617
# Epoch: 175/500, Val_Loss: 0.1692
# Epoch: 176/500, Val_Loss: 0.1642
# Epoch: 177/500, Val_Loss: 0.1714
# Epoch: 178/500, Val_Loss: 0.1731
# Epoch: 179/500, Val_Loss: 0.1593
# Epoch: 180/500, Val_Loss: 0.1562
# Epoch: 181/500, Val_Loss: 0.1610
# Epoch: 182/500, Val_Loss: 0.1634
# Epoch: 183/500, Val_Loss: 0.1624
# Epoch: 184/500, Val_Loss: 0.1632
# Epoch: 185/500, Val_Loss: 0.1687
# Epoch: 186/500, Val_Loss: 0.1688
# Epoch: 187/500, Val_Loss: 0.1661
# Epoch: 188/500, Val_Loss: 0.1596
# Epoch: 189/500, Val_Loss: 0.1611
# Epoch: 190/500, Val_Loss: 0.1664
# Epoch: 191/500, Val_Loss: 0.1783
# Epoch: 192/500, Val_Loss: 0.1664
# Epoch: 193/500, Val_Loss: 0.1687
# Epoch: 194/500, Val_Loss: 0.1692
# Epoch: 195/500, Val_Loss: 0.1674
# Epoch: 196/500, Val_Loss: 0.1608
# Epoch: 197/500, Val_Loss: 0.1941
# Epoch: 198/500, Val_Loss: 0.1642
# Epoch: 199/500, Val_Loss: 0.1611
# Epoch: 200/500, Val_Loss: 0.1706
# Epoch: 201/500, Val_Loss: 0.1892
# Epoch: 202/500, Val_Loss: 0.1678
# Epoch: 203/500, Val_Loss: 0.1636
# Epoch: 204/500, Val_Loss: 0.1713
# Epoch: 205/500, Val_Loss: 0.1645
# Epoch: 206/500, Val_Loss: 0.1666
# Epoch: 207/500, Val_Loss: 0.1656
# Epoch: 208/500, Val_Loss: 0.1654
# Epoch: 209/500, Val_Loss: 0.1710
# Epoch: 210/500, Val_Loss: 0.1669
# Epoch: 211/500, Val_Loss: 0.1656
# Epoch: 212/500, Val_Loss: 0.1896
# Epoch: 213/500, Val_Loss: 0.1634
# Epoch: 214/500, Val_Loss: 0.1734
# Epoch: 215/500, Val_Loss: 0.1591
# Epoch: 216/500, Val_Loss: 0.1651
# Epoch: 217/500, Val_Loss: 0.1660
# Epoch: 218/500, Val_Loss: 0.1613
# Epoch: 219/500, Val_Loss: 0.1752
# Epoch: 220/500, Val_Loss: 0.1704
# Epoch: 221/500, Val_Loss: 0.1784
# Epoch: 222/500, Val_Loss: 0.1806
# Epoch: 223/500, Val_Loss: 0.1632
# Epoch: 224/500, Val_Loss: 0.1716
# Epoch: 225/500, Val_Loss: 0.1650
# Epoch: 226/500, Val_Loss: 0.1652
# Epoch: 227/500, Val_Loss: 0.1635
# Epoch: 228/500, Val_Loss: 0.1707
# Epoch: 229/500, Val_Loss: 0.1695
# Epoch: 230/500, Val_Loss: 0.1695
# Epoch: 231/500, Val_Loss: 0.1708
# Epoch: 232/500, Val_Loss: 0.1749
# Epoch: 233/500, Val_Loss: 0.1610
# Epoch: 234/500, Val_Loss: 0.1723
# Epoch: 235/500, Val_Loss: 0.1641
# Epoch: 236/500, Val_Loss: 0.1582
# Epoch: 237/500, Val_Loss: 0.1732
# Epoch: 238/500, Val_Loss: 0.1670
# Epoch: 239/500, Val_Loss: 0.1659
# Epoch: 240/500, Val_Loss: 0.2292
# Epoch: 241/500, Val_Loss: 0.1704
# Epoch: 242/500, Val_Loss: 0.1656
# Epoch: 243/500, Val_Loss: 0.1658
# Epoch: 244/500, Val_Loss: 0.1693
# Epoch: 245/500, Val_Loss: 0.1683
# Epoch: 246/500, Val_Loss: 0.1647
# Epoch: 247/500, Val_Loss: 0.1610
# Epoch: 248/500, Val_Loss: 0.1662
# Epoch: 249/500, Val_Loss: 0.1639
# Epoch: 250/500, Val_Loss: 0.1660
# Epoch: 251/500, Val_Loss: 0.1740
# Epoch: 252/500, Val_Loss: 0.1692
# Epoch: 253/500, Val_Loss: 0.1702
# Epoch: 254/500, Val_Loss: 0.1702
# Epoch: 255/500, Val_Loss: 0.2192
# Epoch: 256/500, Val_Loss: 0.1575
# Epoch: 257/500, Val_Loss: 0.1686
# Epoch: 258/500, Val_Loss: 0.1771
# Epoch: 259/500, Val_Loss: 0.1748
# Epoch: 260/500, Val_Loss: 0.1733
# Epoch: 261/500, Val_Loss: 0.1602
# Epoch: 262/500, Val_Loss: 0.1722
# Epoch: 263/500, Val_Loss: 0.1667
# Epoch: 264/500, Val_Loss: 0.1658
# Epoch: 265/500, Val_Loss: 0.1650
# Epoch: 266/500, Val_Loss: 0.1657
# Epoch: 267/500, Val_Loss: 0.1831
# Epoch: 268/500, Val_Loss: 0.1749
# Epoch: 269/500, Val_Loss: 0.1718
# Epoch: 270/500, Val_Loss: 0.1688
# Epoch: 271/500, Val_Loss: 0.1756
# Epoch: 272/500, Val_Loss: 0.1841
# Epoch: 273/500, Val_Loss: 0.1714
# Epoch: 274/500, Val_Loss: 0.1638
# Epoch: 275/500, Val_Loss: 0.1708
# Epoch: 276/500, Val_Loss: 0.1713
# Epoch: 277/500, Val_Loss: 0.1752
# Epoch: 278/500, Val_Loss: 0.2476
# Epoch: 279/500, Val_Loss: 0.1810
# Epoch: 280/500, Val_Loss: 0.1666
# Epoch: 281/500, Val_Loss: 0.1588
# Epoch: 282/500, Val_Loss: 0.1641
# Epoch: 283/500, Val_Loss: 0.1575
# Epoch: 284/500, Val_Loss: 0.1660
# Epoch: 285/500, Val_Loss: 0.1741
# Epoch: 286/500, Val_Loss: 0.1646
# Epoch: 287/500, Val_Loss: 0.1737
# Epoch: 288/500, Val_Loss: 0.1631
# Epoch: 289/500, Val_Loss: 0.1707
# Epoch: 290/500, Val_Loss: 0.1685
# Epoch: 291/500, Val_Loss: 0.1739
# Epoch: 292/500, Val_Loss: 0.1719
# Epoch: 293/500, Val_Loss: 0.1841
# Epoch: 294/500, Val_Loss: 0.1726
# Epoch: 295/500, Val_Loss: 0.2189
# Epoch: 296/500, Val_Loss: 0.1548
# Epoch: 297/500, Val_Loss: 0.1642
# Epoch: 298/500, Val_Loss: 0.1653
# Epoch: 299/500, Val_Loss: 0.1631
# Epoch: 300/500, Val_Loss: 0.1696
# Epoch: 301/500, Val_Loss: 0.1732
# Epoch: 302/500, Val_Loss: 0.1778
# Epoch: 303/500, Val_Loss: 0.1604
# Epoch: 304/500, Val_Loss: 0.1615
# Epoch: 305/500, Val_Loss: 0.1711
# Epoch: 306/500, Val_Loss: 0.1622
# Epoch: 307/500, Val_Loss: 0.1772
# Epoch: 308/500, Val_Loss: 0.1788
# Epoch: 309/500, Val_Loss: 0.1782
# Epoch: 310/500, Val_Loss: 0.1645
# Epoch: 311/500, Val_Loss: 0.1808
# Epoch: 312/500, Val_Loss: 0.1660
# Epoch: 313/500, Val_Loss: 0.1680
# Epoch: 314/500, Val_Loss: 0.1797
# Epoch: 315/500, Val_Loss: 0.1626
# Epoch: 316/500, Val_Loss: 0.1916
# Epoch: 317/500, Val_Loss: 0.1653
# Epoch: 318/500, Val_Loss: 0.1816
# Epoch: 319/500, Val_Loss: 0.1731
# Epoch: 320/500, Val_Loss: 0.1741
# Epoch: 321/500, Val_Loss: 0.1670
# Epoch: 322/500, Val_Loss: 0.1790
# Epoch: 323/500, Val_Loss: 0.1741
# Epoch: 324/500, Val_Loss: 0.1687
# Epoch: 325/500, Val_Loss: 0.1805
# Epoch: 326/500, Val_Loss: 0.1799
# Epoch: 327/500, Val_Loss: 0.1748
# Epoch: 328/500, Val_Loss: 0.1667
# Epoch: 329/500, Val_Loss: 0.1827
# Epoch: 330/500, Val_Loss: 0.1673
# Epoch: 331/500, Val_Loss: 0.1801
# Epoch: 332/500, Val_Loss: 0.1690
# Epoch: 333/500, Val_Loss: 0.1610
# Epoch: 334/500, Val_Loss: 0.1870
# Epoch: 335/500, Val_Loss: 0.1757
# Epoch: 336/500, Val_Loss: 0.1636
# Epoch: 337/500, Val_Loss: 0.1831
# Epoch: 338/500, Val_Loss: 0.1740
# Epoch: 339/500, Val_Loss: 0.1718
# Epoch: 340/500, Val_Loss: 0.1775
# Epoch: 341/500, Val_Loss: 0.1721
# Epoch: 342/500, Val_Loss: 0.1712
# Epoch: 343/500, Val_Loss: 0.1697
# Epoch: 344/500, Val_Loss: 0.1818
# Epoch: 345/500, Val_Loss: 0.1771
# Epoch: 346/500, Val_Loss: 0.1872
# Epoch: 347/500, Val_Loss: 0.1718
# Epoch: 348/500, Val_Loss: 0.1943
# Epoch: 349/500, Val_Loss: 0.1855
# Epoch: 350/500, Val_Loss: 0.1788
# Epoch: 351/500, Val_Loss: 0.1716
# Epoch: 352/500, Val_Loss: 0.1760
# Epoch: 353/500, Val_Loss: 0.1675
# Epoch: 354/500, Val_Loss: 0.1889
# Epoch: 355/500, Val_Loss: 0.1770
# Epoch: 356/500, Val_Loss: 0.1732
# Epoch: 357/500, Val_Loss: 0.1819
# Epoch: 358/500, Val_Loss: 0.1796
# Epoch: 359/500, Val_Loss: 0.1773
# Epoch: 360/500, Val_Loss: 0.1807
# Epoch: 361/500, Val_Loss: 0.1697
# Epoch: 362/500, Val_Loss: 0.1863
# Epoch: 363/500, Val_Loss: 0.1824
# Epoch: 364/500, Val_Loss: 0.2004
# Epoch: 365/500, Val_Loss: 0.1932
# Epoch: 366/500, Val_Loss: 0.1750
# Epoch: 367/500, Val_Loss: 0.1817
# Epoch: 368/500, Val_Loss: 0.1845
# Epoch: 369/500, Val_Loss: 0.1949
# Epoch: 370/500, Val_Loss: 0.1794
# Epoch: 371/500, Val_Loss: 0.1859
# Epoch: 372/500, Val_Loss: 0.1795
# Epoch: 373/500, Val_Loss: 0.1837
# Epoch: 374/500, Val_Loss: 0.1805
# Epoch: 375/500, Val_Loss: 0.1806
# Epoch: 376/500, Val_Loss: 0.1824
# Epoch: 377/500, Val_Loss: 0.1838
# Epoch: 378/500, Val_Loss: 0.1734
# Epoch: 379/500, Val_Loss: 0.1902
# Epoch: 380/500, Val_Loss: 0.1860
# Epoch: 381/500, Val_Loss: 0.1988
# Epoch: 382/500, Val_Loss: 0.1924
# Epoch: 383/500, Val_Loss: 0.1915
# Epoch: 384/500, Val_Loss: 0.2020
# Epoch: 385/500, Val_Loss: 0.1738
# Epoch: 386/500, Val_Loss: 0.1778
# Epoch: 387/500, Val_Loss: 0.1842
# Epoch: 388/500, Val_Loss: 0.1768
# Epoch: 389/500, Val_Loss: 0.1666
# Epoch: 390/500, Val_Loss: 0.1755
# Epoch: 391/500, Val_Loss: 0.1838
# Epoch: 392/500, Val_Loss: 0.1863
# Epoch: 393/500, Val_Loss: 0.1716
# Epoch: 394/500, Val_Loss: 0.1949
# Epoch: 395/500, Val_Loss: 0.1735
# Epoch: 396/500, Val_Loss: 0.1755
# Epoch: 397/500, Val_Loss: 0.1909
# Epoch: 398/500, Val_Loss: 0.1870
# Epoch: 399/500, Val_Loss: 0.1735
# Epoch: 400/500, Val_Loss: 0.1755
# Epoch: 401/500, Val_Loss: 0.1839
# Epoch: 402/500, Val_Loss: 0.1849
# Epoch: 403/500, Val_Loss: 0.1850
# Epoch: 404/500, Val_Loss: 0.1815
# Epoch: 405/500, Val_Loss: 0.1826
# Epoch: 406/500, Val_Loss: 0.1781
# Epoch: 407/500, Val_Loss: 0.1760
# Epoch: 408/500, Val_Loss: 0.1901
# Epoch: 409/500, Val_Loss: 0.1923
# Epoch: 410/500, Val_Loss: 0.2098
# Epoch: 411/500, Val_Loss: 0.1822
# Epoch: 412/500, Val_Loss: 0.1870
# Epoch: 413/500, Val_Loss: 0.1729
# Epoch: 414/500, Val_Loss: 0.1831
# Epoch: 415/500, Val_Loss: 0.1686
# Epoch: 416/500, Val_Loss: 0.1829
# Epoch: 417/500, Val_Loss: 0.1801
# Epoch: 418/500, Val_Loss: 0.1898
# Epoch: 419/500, Val_Loss: 0.1922
# Epoch: 420/500, Val_Loss: 0.1860
# Epoch: 421/500, Val_Loss: 0.1771
# Epoch: 422/500, Val_Loss: 0.1828
# Epoch: 423/500, Val_Loss: 0.1813
# Epoch: 424/500, Val_Loss: 0.1744
# Epoch: 425/500, Val_Loss: 0.1804
# Epoch: 426/500, Val_Loss: 0.1783
# Epoch: 427/500, Val_Loss: 0.1725
# Epoch: 428/500, Val_Loss: 0.1979
# Epoch: 429/500, Val_Loss: 0.1824
# Epoch: 430/500, Val_Loss: 0.1788
# Epoch: 431/500, Val_Loss: 0.1859
# Epoch: 432/500, Val_Loss: 0.1766
# Epoch: 433/500, Val_Loss: 0.1868
# Epoch: 434/500, Val_Loss: 0.1947
# Epoch: 435/500, Val_Loss: 0.1947
# Epoch: 436/500, Val_Loss: 0.1847
# Epoch: 437/500, Val_Loss: 0.1808
# Epoch: 438/500, Val_Loss: 0.1860
# Epoch: 439/500, Val_Loss: 0.1780
# Epoch: 440/500, Val_Loss: 0.1861
# Epoch: 441/500, Val_Loss: 0.1790
# Epoch: 442/500, Val_Loss: 0.1752
# Epoch: 443/500, Val_Loss: 0.1800
# Epoch: 444/500, Val_Loss: 0.1657
# Epoch: 445/500, Val_Loss: 0.1833
# Epoch: 446/500, Val_Loss: 0.1837
# Epoch: 447/500, Val_Loss: 0.1784
# Epoch: 448/500, Val_Loss: 0.1815
# Epoch: 449/500, Val_Loss: 0.1918
# Epoch: 450/500, Val_Loss: 0.1875
# Epoch: 451/500, Val_Loss: 0.1891
# Epoch: 452/500, Val_Loss: 0.1864
# Epoch: 453/500, Val_Loss: 0.1901
# Epoch: 454/500, Val_Loss: 0.1821
# Epoch: 455/500, Val_Loss: 0.1947
# Epoch: 456/500, Val_Loss: 0.1886
# Epoch: 457/500, Val_Loss: 0.1824
# Epoch: 458/500, Val_Loss: 0.1889
# Epoch: 459/500, Val_Loss: 0.1705
# Epoch: 460/500, Val_Loss: 0.1852
# Epoch: 461/500, Val_Loss: 0.1799
# Epoch: 462/500, Val_Loss: 0.1842
# Epoch: 463/500, Val_Loss: 0.1759
# Epoch: 464/500, Val_Loss: 0.2060
# Epoch: 465/500, Val_Loss: 0.1924
# Epoch: 466/500, Val_Loss: 0.1799
# Epoch: 467/500, Val_Loss: 0.1837
# Epoch: 468/500, Val_Loss: 0.1837
# Epoch: 469/500, Val_Loss: 0.1793
# Epoch: 470/500, Val_Loss: 0.1852
# Epoch: 471/500, Val_Loss: 0.1980
# Epoch: 472/500, Val_Loss: 0.1835
# Epoch: 473/500, Val_Loss: 0.1756
# Epoch: 474/500, Val_Loss: 0.1814
# Epoch: 475/500, Val_Loss: 0.1684
# Epoch: 476/500, Val_Loss: 0.1865
# Epoch: 477/500, Val_Loss: 0.1733
# Epoch: 478/500, Val_Loss: 0.1713
# Epoch: 479/500, Val_Loss: 0.1896
# Epoch: 480/500, Val_Loss: 0.1793
# Epoch: 481/500, Val_Loss: 0.1819
# Epoch: 482/500, Val_Loss: 0.1623
# Epoch: 483/500, Val_Loss: 0.1805
# Epoch: 484/500, Val_Loss: 0.1757
# Epoch: 485/500, Val_Loss: 0.1821
# Epoch: 486/500, Val_Loss: 0.1850
# Epoch: 487/500, Val_Loss: 0.1783
# Epoch: 488/500, Val_Loss: 0.1705
# Epoch: 489/500, Val_Loss: 0.1846
# Epoch: 490/500, Val_Loss: 0.1745
# Epoch: 491/500, Val_Loss: 0.1713
# Epoch: 492/500, Val_Loss: 0.1797
# Epoch: 493/500, Val_Loss: 0.1780
# Epoch: 494/500, Val_Loss: 0.1690
# Epoch: 495/500, Val_Loss: 0.1744
# Epoch: 496/500, Val_Loss: 0.1652
# Epoch: 497/500, Val_Loss: 0.1904
# Epoch: 498/500, Val_Loss: 0.1706
# Epoch: 499/500, Val_Loss: 0.1650
# Epoch: 500/500, Val_Loss: 0.1663
# MSE: 0.1880, MAE: 0.1816

# %%
epochs = range(1, epochs+1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, training_loss, label="Training loss", color="blue", linestyle="--", linewidth=2)
plt.plot(epochs, validation_loss, label="Validation loss", color="orange", linestyle="-", linewidth=2)

plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Loss", fontsize=14)
plt.title("Loss vs. Epochs for SHL Hotel", fontsize=16, weight="bold")

plt.grid(color="gray", linestyle="--", linewidth=0.5, alpha=0.7)

plt.legend(fontsize=12)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()
